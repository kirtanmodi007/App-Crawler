# %%
import pandas as pd

# %%
my_Data_Frame = pd.read_csv('new_free_ios.csv')

# %%
my_Data_Frame.shape
# Out:
# (200, 12)

# %%
my_Data_Frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
# id              200 non-null int64
# appId           0 non-null float64
# description     0 non-null float64
# title           200 non-null object
# icon            200 non-null object
# url             200 non-null object
# developer       200 non-null object
# developerUrl    200 non-null object
# developerId     200 non-null int64
# genres          200 non-null object
# genreIds        200 non-null object
# released        200 non-null object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 18.9+ KB

# %%
my_Data_Frame
# Out:
#              id  appId  description                           title  \
# 0    1374403536    NaN          NaN        BitLife - Life Simulator
# 1    1350301428    NaN          NaN                          ZEPETO
# 2    1437370468    NaN          NaN                   Fire Balls 3D
# 3    1252850847    NaN          NaN        NBA 2K Mobile Basketball
# 4     544007664    NaN          NaN  YouTube: Watch, Listen, Stream
# ..          ...    ...          ...                             ...
# 195   909319292    NaN          NaN   Google Calendar: Time Planner
# 196  1146465836    NaN          NaN             Hill Climb Racing 2
# 197   553834731    NaN          NaN                Candy Crush Saga
# 198  1216575026    NaN          NaN             Matchington Mansion
# 199   472014516    NaN          NaN                          Kohl's
#
#                                                   icon  \
# 0    https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# ...
